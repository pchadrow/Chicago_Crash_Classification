# %%
import pandas as pd

from pandas_profiling import ProfileReport
from Datafun import column_cutter
# Out:
# C:\Users\damni\anaconda3\envs\learn-env\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# The overview of our data showed that we have many columns in all three of the datasets that are missing the majority of its data in several columns. What we'll with here is removing all columns from the datasets that are missing an overwhelming majority of their observations.

# %%
df = pd.read_csv('../raw_data/Traffic_Crashes_-_People.csv')
People = column_cutter(df, .8)
# Out:
# C:\Users\damni\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12,13,20,21,22,23,24,25,26,27,29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# A total of 9 columns were removed due to 80.0% of the values missing.
# The columns were
#  ['SEAT_NO', 'HOSPITAL', 'EMS_AGENCY', 'EMS_RUN_NO', 'PEDPEDAL_ACTION', 'PEDPEDAL_VISIBILITY', 'PEDPEDAL_LOCATION', 'BAC_RESULT VALUE', 'CELL_PHONE_USE']

# %%
People.head()
# Out:
#   PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0       O10      DRIVER  2e31858c0e411f0bdcb337fb7c415aa93763cf2f23e02f...
# 1      O100      DRIVER  e73b35bd7651b0c6693162bee0666db159b28901437009...
# 2     O1000      DRIVER  f2b1adeb85a15112e4fb7db74bff440d6ca53ff7a21e10...
# 3    O10000      DRIVER  15a3e24fce3ce7cd2b02d44013d1a93ff2fbdca80632ec...
# 4   O100001      DRIVER  2fcefeab458932d8b1b12e103c18c50adc659943cccd4b...
#
#       RD_NO  VEHICLE_ID              CRASH_DATE       CITY STATE ZIPCODE SEX  \
# 0  HY368708        10.0  08/04/2015 12:40:00 PM    CHICAGO    IL   60641   M
# 1  HY374018        96.0  07/31/2015 05:50:00 PM  ELK GROVE    IL   60007   M
# 2  HY407431       954.0  09/02/2015 11:45:00 AM    CHICAGO    IL     NaN   M
# 3  HY484148      9561.0  10/31/2015 09:30:00 PM     SKOKIE    IL   60076   M
# 4  HZ525619     96762.0  11/15/2016 05:45:00 PM        NaN   NaN     NaN   X
#
# ...

# %%
People.to_csv('People.csv')

# %%
df = pd.read_csv('../raw_data/Traffic_Crashes_-_Vehicles.csv')
Vehicle = column_cutter(df, .7)
# Out:
# C:\Users\damni\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (19,21,40,41,42,44,48,49,50,55,58,59,61) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# A total of 54 columns were removed due to 70.0% of the values missing.
# The columns were
# ...

# %%
Vehicle.head()
# Out:
#    CRASH_UNIT_ID                                    CRASH_RECORD_ID     RD_NO  \
# 0             10  2e31858c0e411f0bdcb337fb7c415aa93763cf2f23e02f...  HY368708
# 1            100  e73b35bd7651b0c6693162bee0666db159b28901437009...  HY374018
# 2           1000  f2b1adeb85a15112e4fb7db74bff440d6ca53ff7a21e10...  HY407431
# 3          10000  15a3e24fce3ce7cd2b02d44013d1a93ff2fbdca80632ec...  HY484148
# 4         100000  1d3c178880366c77deaf06b8c3198429112a1c8e8807ed...  HZ518934
#
#                CRASH_DATE  UNIT_NO UNIT_TYPE  VEHICLE_ID  \
# 0  08/04/2015 12:40:00 PM        1    DRIVER        10.0
# 1  07/31/2015 05:50:00 PM        1    DRIVER        96.0
# 2  09/02/2015 11:45:00 AM        1    DRIVER       954.0
# 3  10/31/2015 09:30:00 PM        2    DRIVER      9561.0
# 4  11/16/2016 01:00:00 PM        2    PARKED     96745.0
#
#                          MAKE                 MODEL LIC_PLATE_STATE  \
# 0                        FORD                 Focus              IL
# ...

# %%
Vehicle.to_csv('Vehicle.csv')

# %%
df = pd.read_csv('../raw_data/Traffic_Crashes_-_Crashes.csv')
Crashes = column_cutter(df, .9)
# Out:
# A total of 8 columns were removed due to 90.0% of the values missing.
# The columns were
#  ['CRASH_DATE_EST_I', 'NOT_RIGHT_OF_WAY_I', 'PHOTOS_TAKEN_I', 'STATEMENTS_TAKEN_I', 'DOORING_I', 'WORK_ZONE_I', 'WORK_ZONE_TYPE', 'WORKERS_PRESENT_I']

# %%
Crashes.head()
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  073682ef84ff827659552d4254ad1b98bfec24935cc9cc...  JB460108
# 1  1560fb8a1e32b528fef8bfd677d2b3fc5ab37278b157fa...  JC325941
# 2  009e9e67203442370272e1a13d6ee51a4155dac65e583d...  JA329216
# 3  00e47f189660cd8ba1e85fc63061bf1d8465184393f134...  JC194776
# 4  0126747fc9ffc0edc9a38abb83d80034f897db0f739eef...  JB200478
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  10/02/2018 06:30:00 PM                  10            NO CONTROLS
# 1  06/27/2019 04:00:00 PM                  45            NO CONTROLS
# 2  06/30/2017 04:00:00 PM                  35      STOP SIGN/FLASHER
# 3  03/21/2019 10:50:00 PM                  30         TRAFFIC SIGNAL
# 4  03/26/2018 02:23:00 PM                  35            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# 0           NO CONTROLS             CLEAR                DARKNESS
# ...

# %%
Crashes.to_csv('Crashes.csv')

# %%
Crashes['LANE_CNT'].value_counts()
# Out:
# 2.0          90913
# 4.0          49492
# 1.0          32500
# 3.0           8644
# 0.0           8011
# 6.0           4494
# 5.0           1935
# 8.0           1906
# 7.0            184
# 10.0           161
# 99.0           109
# 9.0             65
# 11.0            30
# 12.0            29
# 20.0            15
# 22.0            13
# 16.0             7
# 15.0             7
# 14.0             5
# 30.0             5
# 40.0             4
# 21.0             3
# 60.0             3
# 25.0             2
# 100.0            2
# 45.0             1
# 218474.0         1
# 80.0             1
# 902.0            1
# 400.0            1
# 17.0             1
# 35.0             1
# 1191625.0        1
# 44.0             1
# 299679.0         1
# 19.0             1
# 28.0             1
# 433634.0         1
# 13.0             1
# 41.0             1
# 24.0             1
# Name: LANE_CNT, dtype: int64

# %% [markdown]
# While I feel this information would prove useful in prediciting causes of crashes, it's currently missing over 50% of the information and has a very large portion of placeholder data as I find it hard to belive any roadway in Chicago has 10+ lanes. In my next notebook we will attempt to remedy this problem along with some other problem columns before attempting to make our core classifier.

# %%
Test.head()
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  073682ef84ff827659552d4254ad1b98bfec24935cc9cc...  JB460108
# 1  1560fb8a1e32b528fef8bfd677d2b3fc5ab37278b157fa...  JC325941
# 2  009e9e67203442370272e1a13d6ee51a4155dac65e583d...  JA329216
# 3  00e47f189660cd8ba1e85fc63061bf1d8465184393f134...  JC194776
# 4  0126747fc9ffc0edc9a38abb83d80034f897db0f739eef...  JB200478
#
#                CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# 0  10/02/2018 06:30:00 PM                  10            NO CONTROLS
# 1  06/27/2019 04:00:00 PM                  45            NO CONTROLS
# 2  06/30/2017 04:00:00 PM                  35      STOP SIGN/FLASHER
# 3  03/21/2019 10:50:00 PM                  30         TRAFFIC SIGNAL
# 4  03/26/2018 02:23:00 PM                  35            NO CONTROLS
#
#        DEVICE_CONDITION WEATHER_CONDITION      LIGHTING_CONDITION  \
# 0           NO CONTROLS             CLEAR                DARKNESS
# ...

# %%
Test.set_index(keys=['TRAFFIC_CONTROL_DEVICE', 'CRASH_RECORD_ID']).stack().shape
# Out:
# (15138171,)

# %%
Test.shape
# Out:
# (416198, 39)

# %%
People.set_index(keys=['CRASH_RECORD_ID', 'RD_NO']).sort_index()
# Out:
#                                                             PERSON_ID  \
# CRASH_RECORD_ID                                    RD_NO
# 00002c0771fb6f2c70ba775b7f6b501608cadea85c1dd13... HZ228060    O40893
#                                                    HZ228060    O40894
# 000043c6564ec4d54bc4efd957d97ca97f38a965dd64b46... JC556033   O807770
# 000070ed7a6357c3298f5edc6fb7d5ce925a10f46660f37... HZ486518    O89591
#                                                    HZ486518    O89592
# ...                                                               ...
# ffffc0eaf9bc22a04bf318b62e0e1c5ec59a4f3c0c34936... JA420994   O212345
# ffffe467b0d2d95c897e8c2721941f87dede1661a3b60ce... JB356563   O436457
#                                                    JB356563   O436458
# ffffe577251dc1cc67f2f823b595e5028427a210e2a40e7... JD158296   O846339
#                                                    JD158296   O846340
#
# ...
